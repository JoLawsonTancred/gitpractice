# %%
#Import cifar100 dataset for image classification training

from keras.datasets import cifar100
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode="fine")

# %%
import autokeras as ak

lear_classifier = ak.ImageClassifier(max_trials=1)
lear_classifier.fit(X_train, y_train, epochs=5)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./image_classifier/oracle.json
# INFO:tensorflow:Reloading Tuner from ./image_classifier/tuner0.json
# 2022-03-26 20:56:21.792951: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Search: Running Trial #2
#
# Value             |Best Value So Far |Hyperparameter
# resnet            |vanilla           |image_block_1/block_type
# True              |True              |image_block_1/normalize
# True              |False             |image_block_1/augment
# True              |None              |image_block_1/image_augmentation_1/horizontal_flip
# True              |None              |image_block_1/image_augmentation_1/vertical_flip
# 0                 |None              |image_block_1/image_augmentation_1/contrast_factor
# 0                 |None              |image_block_1/image_augmentation_1/rotation_factor
# 0.1               |None              |image_block_1/image_augmentation_1/translation_factor
# 0                 |None              |image_block_1/image_augmentation_1/zoom_factor
# False             |None              |image_block_1/res_net_block_1/pretrained
# resnet50          |None              |image_block_1/res_net_block_1/version
# True              |None              |image_block_1/res_net_block_1/imagenet_size
# global_avg        |flatten           |classification_head_1/spatial_reduction_1/reduction_type
# 0                 |0.5               |classification_head_1/dropout
# adam              |adam              |optimizer
# 0.001             |0.001             |learning_rate
#
# Epoch 1/5
#   19/1251 [..............................] - ETA: 2:38:54 - loss: 6.6543 - accuracy: 0.0247
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/38/p1550j817hd1dn7l8r9v5m_r0000gn/T/ipykernel_14060/2797862746.py in <module>
#       2
#       3 lear_classifier = ak.ImageClassifier(max_trials=1)
# ----> 4 lear_classifier.fit(X_train, y_train, epochs=5)
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/tasks/image.py in fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     162                 validation loss values and validation metrics values (if applicable).
#     163         """
# --> 164         history = super().fit(
#     165             x=x,
#     166             y=y,
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/auto_model.py in fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, verbose, **kwargs)
#     289             )
#     290
# --> 291         history = self.tuner.search(
#     292             x=dataset,
#     293             epochs=epochs,
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/engine/tuner.py in search(self, epochs, callbacks, validation_split, verbose, **fit_kwargs)
#     191         self._try_build(hp)
#     192         self.oracle.update_space(hp)
# --> 193         super().search(
#     194             epochs=epochs, callbacks=new_callbacks, verbose=verbose, **fit_kwargs
#     195         )
#
# /opt/anaconda3/lib/python3.9/site-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     177
#     178             self.on_trial_begin(trial)
# --> 179             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     180             # `results` is None indicates user updated oracle in `run_trial()`.
#     181             if results is None:
#
# /opt/anaconda3/lib/python3.9/site-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     292             callbacks.append(model_checkpoint)
#     293             copied_kwargs["callbacks"] = callbacks
# --> 294             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     295
#     296             histories.append(obj_value)
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#      99         self.adapt(model, kwargs["x"])
#     100
# --> 101         _, history = utils.fit_with_adaptive_batch_size(
#     102             model, self.hypermodel.batch_size, **kwargs
#     103         )
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/utils/utils.py in fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs)
#      87
#      88 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
# ---> 89     history = run_with_adaptive_batch_size(
#      90         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      91     )
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/utils/utils.py in run_with_adaptive_batch_size(batch_size, func, **fit_kwargs)
#     100     while batch_size > 0:
#     101         try:
# --> 102             history = func(x=x, validation_data=validation_data, **fit_kwargs)
#     103             break
#     104         except tf.errors.ResourceExhaustedError as e:
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/utils/utils.py in <lambda>(**kwargs)
#      88 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
#      89     history = run_with_adaptive_batch_size(
# ---> 90         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      91     )
#      92     return model, history
#
# /opt/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#Search images by Edward Lear in the V&A collection

import requests
import pandas as pd

vam_response = pd.read_csv('https://api.vam.ac.uk/v2/objects/search?q_actor=edward%20lear&images_exist=1&response_format=csv&page_size=50')
vam_waterlilies_all_df = pd.DataFrame(vam_response)
vam_waterlilies_all_df.head(10)
# Out:
#    accessionNumber  accessionYear systemNumber    objectType  \
# 0        P.13-1961         1961.0     O1042326   Watercolour
# 1     CIRC.81-1974         1974.0     O1038702    Lithograph
# 2     CIRC.83-1974         1974.0     O1038681    Lithograph
# 3        P.19-1946         1946.0      O134413  Oil painting
# 4       E.739-1939         1939.0      O729747       Drawing
# 5       E.750-1939         1939.0      O729736       Drawing
# 6       E.716-1950         1950.0      O595386       Drawing
# 7         P.1-1930         1930.0     O1225507   Watercolour
# 8         P.2-1930         1930.0     O1225506   Watercolour
# 9         P.3-1930         1930.0     O1225505   Watercolour
# 10          SD.567            NaN      O145971       Drawing
# 11          SD.566            NaN      O145970       Drawing
# 12          SD.565            NaN      O145969   Watercolour
# 13          SD.564            NaN      O145968   Watercolour
# 14          SD.563            NaN      O145967   Watercolour
# 15          SD.562            NaN      O145966   Watercolour
# 16          SD.561            NaN      O145965       Drawing
# 17          SD.560            NaN      O145964       Drawing
# 18      E.762-1939         1939.0      O729724       Drawing
# 19      E.769-1939         1939.0      O729717       Drawing
#
#                    _primaryTitle _primaryPlace _primaryMaker__name  \
# 0                          Corfu       Britain        Lear, Edward
# 1                         Tivoli         Italy         Edward Lear
# 2                     Collepardo         Italy         Edward Lear
# 3                          Corfu           NaN        Lear, Edward
# 4                            NaN         Italy        Lear, Edward
# 5                            NaN       Britain        Lear, Edward
# 6                            NaN         Italy         Edward Lear
# 7                   Chorepiskopi        Greece         Edward Lear
# 8                     Tripolitza        Greece         Edward Lear
# 9                    River Scene       Britain         Edward Lear
# 10                   Cedar trees           NaN        Lear, Edward
# 11               A seated figure           NaN        Lear, Edward
# 12  Temple at Derr, Nubia, Egypt  North Africa        Lear, Edward
# 13                  Near Jericho        Jordan        Lear, Edward
# 14                        Masada        Israel        Lear, Edward
# 15                         Petra        Jordan        Lear, Edward
# 16                     Mt. Sinai         Egypt        Lear, Edward
# 17                     Mt. Sinai         Egypt        Lear, Edward
# 18       The Plym at Shaw Bridge         Devon        Lear, Edward
# 19                  Downe Thomas         Devon        Lear, Edward
#
#    _primaryMaker__association       _primaryDate _primaryImageId  \
# 0                      artist               1862      2006AE8023
# 1                      artist               1842      2011EU2159
# 2                      artist               1842      2011EU2162
# 3            painter (artist)  ca. 1855-ca. 1863      2007BP0822
# 4                      artist               1838      2006BE6165
# 5                      artist               1837      2006BE6164
# 6                      artist           ca. 1860      2018KR6495
# 7                      artist               1856      2017KA0615
# 8                      artist               1849      2017KA0645
# 9                      artist               1860      2006AP0290
# 10                     artist          1858-1860      2008BT7959
# 11                     artist       19th century      2008BT7944
# 12                     artist               1867      2011FA5571
# 13           painter (artist)               1858      2008BV6264
# 14                    painter               1858      2008BT7948
# 15           painter (artist)               1858      2008BV6254
# 16                     artist           ca. 1865      2008BT7946
# 17                     artist               1849      2008BT7955
# 18                     artist       23 June 1837      2009CA1892
# 19                     artist       27 June 1837      2009CA1883
#
#    _sampleMaterial     _sampleTechnique    _sampleStyle  \
# 0      watercolour                  NaN             NaN
# 1    printer's ink          lithography             NaN
# 2    printer's ink          lithography             NaN
# 3        oil paint         oil painting  British School
# 4        kaolinite              drawing             NaN
# 5           pencil              drawing             NaN
# 6           pencil              drawing             NaN
# 7      Watercolour  Watercolour drawing             NaN
# 8      Watercolour  Watercolour drawing             NaN
# 9      Watercolour  Watercolour drawing             NaN
# 10             NaN                  NaN  British School
# 11             NaN                  NaN  British School
# 12     watercolour  watercolour drawing  British School
# 13     watercolour  watercolour drawing  British School
# 14     watercolour  watercolour drawing  British School
# 15     watercolour  watercolour drawing  British School
# 16     pen and ink              drawing  British School
# 17     pen and ink              drawing  British School
# 18          pencil              drawing             NaN
# 19          pencil              drawing             NaN
#
#             _currentLocation__displayName  _objectContentWarning  \
# 0   Prints & Drawings Study Room, level F                  False
# 1   Prints & Drawings Study Room, level D                  False
# 2   Prints & Drawings Study Room, level D                  False
# 3   Prints & Drawings Study Room, level H                  False
# 4   Prints & Drawings Study Room, level D                  False
# 5   Prints & Drawings Study Room, level D                  False
# 6   Prints & Drawings Study Room, level H                  False
# 7   Prints & Drawings Study Room, level H                  False
# 8   Prints & Drawings Study Room, level H                  False
# 9   Prints & Drawings Study Room, level H                  False
# 10  Prints & Drawings Study Room, level D                  False
# 11  Prints & Drawings Study Room, level D                  False
# 12  Prints & Drawings Study Room, level D                  False
# 13  Prints & Drawings Study Room, level D                  False
# 14  Prints & Drawings Study Room, level D                  False
# 15  Prints & Drawings Study Room, level D                  False
# 16  Prints & Drawings Study Room, level D                  False
# 17  Prints & Drawings Study Room, level D                  False
# 18  Prints & Drawings Study Room, level D                  False
# 19  Prints & Drawings Study Room, level D                  False
#
#     _imageContentWarning
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# 5                  False
# 6                  False
# 7                  False
# 8                  False
# 9                  False
# 10                 False
# 11                 False
# 12                 False
# 13                 False
# 14                 False
# 15                 False
# 16                 False
# 17                 False
# 18                 False
# 19                 False

# %%
#Convert image of bird (https://collections.vam.ac.uk/item/O1025328/drawing-lear-edward/) into correct size for neural network

import requests
from tensorflow.keras.preprocessing import image
from PIL import Image

req = requests.get("https://api.vam.ac.uk/v2/object/O1025328")
lamp = req.json()
lamp_thumbnail_url = lamp['meta']['images']['_primary_thumbnail']
response = requests.get(lamp_thumbnail_url, stream=True)
img_array = None
img = Image.open(response.raw)
img = img.convert('RGB')
img = img.resize((32,32), Image.NEAREST)
img_array = image.img_to_array(img)

# %%
#Get prediction

import numpy as np

predictions = lear_classifier.predict(np.array([img_array]))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /var/folders/38/p1550j817hd1dn7l8r9v5m_r0000gn/T/ipykernel_13605/2686843259.py in <module>
#       1 import numpy as np
#       2
# ----> 3 predictions = lear_classifier.predict(np.array([img_array]))
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/auto_model.py in predict(self, x, batch_size, verbose, **kwargs)
#     448         self._check_data_format((x, None), predict=True)
#     449         dataset = self._adapt(x, self.inputs, batch_size)
# --> 450         pipeline = self.tuner.get_best_pipeline()
#     451         model = self.tuner.get_best_model()
#     452         dataset = pipeline.transform_x(dataset)
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/engine/tuner.py in get_best_pipeline(self)
#      65
#      66     def get_best_pipeline(self):
# ---> 67         return pipeline_module.load_pipeline(self.best_pipeline_path)
#      68
#      69     def _pipeline_path(self, trial_id):
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/pipeline.py in load_pipeline(filepath, custom_objects)
#      74         custom_objects = {}
#      75     with tf.keras.utils.custom_object_scope(custom_objects):
# ---> 76         return Pipeline.from_config(io_utils.load_json(filepath))
#      77
#      78
#
# /opt/anaconda3/lib/python3.9/site-packages/autokeras/utils/io_utils.py in load_json(path)
#      32 def load_json(path):
#      33     with tf.io.gfile.GFile(path, "r") as f:
# ---> 34         obj = f.read()
#      35     return json.loads(obj)
#      36
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/lib/io/file_io.py in read(self, n)
#     112       string if in string (regular) mode.
#     113     """
# --> 114     self._preread_check()
#     115     if n == -1:
#     116       length = self.size() - self.tell()
#
# /opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/lib/io/file_io.py in _preread_check(self)
#      74         raise errors.PermissionDeniedError(None, None,
#      75                                            "File isn't open for reading")
# ---> 76       self._read_buf = _pywrap_file_io.BufferedInputStream(
#      77           compat.path_to_str(self.__name), 1024 * 512)
#      78
#
# NotFoundError: ./image_classifier/best_pipeline; No such file or directory
